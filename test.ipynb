# %%
# !nvidia-smi
# Out:
# Tue Dec  2 11:05:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 577.03                 Driver Version: 577.03         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   54C    P8              1W /   50W |       9MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import numpy as np
import torch

# ---------------------------------------------------------------
# 1. Include the model class definition EXACTLY as in training
# ---------------------------------------------------------------
class NextGameRecommender:
    def __init__(self, train_matrix, similarity_matrix, popularity_scores, alpha=0.7,
                 device=None, densify_similarity_auto_cap_bytes=1_000_000_000):
        self.train_matrix = train_matrix
        self.similarity_matrix = similarity_matrix
        self.alpha = alpha
        self.device = torch.device("cpu")  # force CPU for testing
        pop = torch.as_tensor(popularity_scores, dtype=torch.float32)
        self.popularity_t = pop.flatten()
        self.n_items = int(self.popularity_t.numel())

    def recommend(self, user_idx, k=10, exclude_owned=True):
        return []

# ---------------------------------------------------------------
# 2. Load pickle safely on CPU
# ---------------------------------------------------------------
PATH = "trained_models.pkl"

try:
    model = torch.load(
        PATH,
        map_location=torch.device("cpu"),
        weights_only=False
    )
    print("✓ Loaded successfully — FILE IS NOT CORRUPTED!")
except Exception as e:
    print("✗ FAILED:", e)
# Out:
# ✗ FAILED: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
import torch
import pickle

# 1. Import your custom model class

MODEL_PATH = "trained_models.pkl"

try:
    print("Loading on CPU...")
    model = torch.load(
        MODEL_PATH,
        map_location=torch.device("cpu"),
        weights_only=False
    )
    print("✓ Model loaded successfully on CPU!")

except Exception as e:
    print("✗ FAILED:", e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 5
#       2 import pickle
#       4 # 1. Import your custom model class
# ----> 5 from app import NextGameRecommender   # update this path if needed
#       7 MODEL_PATH = "trained_models.pkl"
#       9 try:
#
# File C:\Data_science_projects\Game Recommendation System\PlayNext\app.py:7
#       5 import pickle
#       6 import numpy as np
# ----> 7 from flask import Flask, render_template, request, jsonify
#       8 import torch
#       9 from pathlib import Path
#
# ModuleNotFoundError: No module named 'flask'

# %%
import pickle

PATH = "mappings.pkl"   # or whatever your file is actually called

try:
    with open(PATH, "rb") as f:
        mapping = pickle.load(f)

    print("✓ Mapping file loaded successfully!")
    print("Type:", type(mapping))

    # Inspect keys
    if isinstance(mapping, dict):
        print("Keys:", list(mapping.keys())[:20])
    else:
        print("Not a dictionary")

except Exception as e:
    print("✗ FAILED:", e)
# Out:
# ✓ Mapping file loaded successfully!
# Type: <class 'dict'>
# Keys: ['user_to_idx', 'idx_to_user', 'item_to_idx', 'idx_to_item', 'bundle_to_idx', 'idx_to_bundle']
